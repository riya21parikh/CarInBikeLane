# %% [markdown]
# # Bike Lane Blockage Detection Model
#
# This notebook implements a convolutional neural network (CNN) model to detect whether or not bike lanes are blocked. The model is trained on a dataset of images of bike lanes, some of which are blocked and some of which are not. The model is then evaluated on a test dataset to measure its accuracy. The notebook also includes code to visualize the training and testing metrics, such as the accuracy and loss of the model over time.

# %% [markdown]
# ## Setup and Imports
# Import required libraries and set up constants

# %%
# !pip install tensorflow-macos tensorflow-metal numpy scikit-learn matplotlib pillow
# Out:
# Requirement already satisfied: tensorflow-macos in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (2.16.2)
# Requirement already satisfied: tensorflow-metal in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (1.1.0)
# Requirement already satisfied: numpy in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: matplotlib in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (3.9.3)
# Requirement already satisfied: pillow in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (11.0.0)
# Requirement already satisfied: tensorflow==2.16.2 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow-macos) (2.16.2)
# Requirement already satisfied: libclang>=13.0.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.32.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.2.0)
# Requirement already satisfied: packaging in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (23.2)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.6.0)
# Requirement already satisfied: keras>=3.0.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.68.1)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (24.3.25)
# Requirement already satisfied: six>=1.12.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.16.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.16.2)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.1.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.25.5)
# Requirement already satisfied: setuptools in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (58.1.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.12.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.8.0)
# Requirement already satisfied: wheel~=0.35 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorflow-metal) (0.45.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from matplotlib) (4.55.2)
# Requirement already satisfied: cycler>=0.10 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: rich in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (13.9.4)
# Requirement already satisfied: namex in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.0.8)
# Requirement already satisfied: optree in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.13.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (6.8.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.1.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import matplotlib
import platform
import time

# %%
# Constants used throughout the code
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 64  # Increased batch size for faster processing
EPOCHS = 20

# %% [markdown]
# ## Image Loading and Preprocessing
# Function to load and preprocess images from the dataset

# %%
def load_and_preprocess_images(directory, max_per_class=None):
    """
    Load and preprocess images with an optional limit per class.
    Args:
        directory: Base directory containing 'blocked' and 'notblocked' subdirectories
        max_per_class: Max number of images to load per class (if None, load all).  Used for testing.
    """
    
    # where I store the image files and their corresponding labels
    images = []
    labels = []
    
    print("\nLoading images with blocked bike lanes:")
    
    # Load blocked images
    blocked_dir = os.path.join(directory, 'blocked2')
    blocked_files = [f for f in os.listdir(blocked_dir) if f.lower().endswith('.png')]
    if max_per_class:
        blocked_files = blocked_files[:max_per_class]
    
    for i, img_name in enumerate(blocked_files, 1):
        if i % 25 == 0:  # Show progress every 10 images
            print(f"Processing blocked image {i}/{len(blocked_files)}")
        img_path = os.path.join(blocked_dir, img_name)
        # Load the image using Keras' load_img and then convert it to an array
        img = load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
        img_array = img_to_array(img)
        images.append(img_array)
        labels.append(1)  # 1 for blocked
    
    print("\nLoading images with unblocked bike lanes:")
    
    # Load not blocked images
    notblocked_dir = os.path.join(directory, 'notblocked')
    notblocked_files = [f for f in os.listdir(notblocked_dir) if f.lower().endswith('.png')]
    if max_per_class:
        notblocked_files = notblocked_files[:max_per_class]
    
    for i, img_name in enumerate(notblocked_files, 1):
        if i % 25 == 0:  # Show progress every 10 images
            print(f"Processing non-blocked image {i}/{len(notblocked_files)}")
        img_path = os.path.join(notblocked_dir, img_name)
        # Load the image using Keras' load_img and then convert it to an array
        img = load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
        img_array = img_to_array(img)
        images.append(img_array)
        labels.append(0)  # 0 for not blocked
    
    return np.array(images), np.array(labels)

# %% [markdown]
# ## Model Architecture
# Define the CNN model architecture

# %%
def create_model():
    """
    Creates a CNN model for binary image classification (blocked vs not blocked).
    Architecture: 3 Conv2D layers with max pooling, followed by dense layers.
    """
    model = models.Sequential([
        # First Convolutional Layer
        # 32 filters of size 3x3, ReLU activation
        # Input shape: 224x224 RGB images (3 channels)
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        # Max Pooling: Reduces spatial dimensions by half (112x112)
        layers.MaxPooling2D((2, 2)),
        
        # Second Convolutional Layer
        # 64 filters of size 3x3, increased filters for more feature detection
        layers.Conv2D(64, (3, 3), activation='relu'),
        # Max Pooling: Further reduces dimensions (56x56)
        layers.MaxPooling2D((2, 2)),
        
        # Third Convolutional Layer
        # 64 filters of size 3x3, maintains number of filters
        layers.Conv2D(64, (3, 3), activation='relu'),
        
        # Flatten: Converts 3D feature maps to 1D vector
        layers.Flatten(),
        
        # Dense Layer: 64 neurons for high-level feature combination
        layers.Dense(64, activation='relu'),
        
        # Output Layer: Single neuron with sigmoid for binary classification
        # Output: 0 (not blocked) or 1 (blocked)
        layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ## Utility Functions
# Helper functions for data preprocessing and GPU setup

# %%
def normalize_images(images):
    """Normalize image pixel values to [0,1] range."""
    return images.astype('float32') / 255.0

def split_dataset(images, labels, test_size=0.2, random_state=42):
    """Split dataset into training and testing sets."""
    return train_test_split(
        images, labels, test_size=test_size, random_state=random_state
    )

def setup_gpu():
    """Configure GPU settings for Metal acceleration."""
    tf.config.experimental.set_visible_devices(
        tf.config.list_physical_devices('GPU'),
        'GPU'
    )

# %% [markdown]
# ## Training Functions
# Functions for model training and evaluation

# %%
def train_model(model, X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2):
    """Train the model and return training history."""
    print(f"\nTraining with {epochs} epochs, batch size {batch_size}")
    print(f"Using {validation_split*100}% of training data for validation")
    
    class TrainingProgressCallback(tf.keras.callbacks.Callback):
        def on_epoch_begin(self, epoch, logs=None):
            print(f"\nEpoch {epoch + 1}/{epochs}")
        
        def on_batch_end(self, batch, logs=None):
            if batch % 5 == 0:  # Show progress every 5 batches
                print(".", end="", flush=True)
    
    return model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=validation_split,
        callbacks=[TrainingProgressCallback()],
        verbose=0
    )

def evaluate_model(model, X_test, y_test):
    """Evaluate model on test data and return metrics."""
    print("\nEvaluating model on test data...")
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    metrics = {
        'test_loss': test_loss,
        'test_accuracy': test_accuracy
    }
    print(f"Evaluation complete!")
    return metrics

# %% [markdown]
# ## Visualization Functions
# Functions for plotting training history and printing system information

# %%
def plot_training_history(history):
    """Plot training and validation metrics."""
    print("\nGenerating training history plots...")
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    print("Displaying plots...")
    plt.show()

def print_versions():
    """Print versions of important packages."""
    print("\nPackage versions:")
    print(f"Python: {platform.python_version()}")
    print(f"TensorFlow: {tf.__version__}")
    print(f"NumPy: {np.__version__}")
    print(f"Scikit-learn: {sklearn.__version__}")
    print(f"Matplotlib: {matplotlib.__version__}")
    print(f"Keras: {tf.keras.__version__}")
    
    # Print GPU information if available
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        print("\nGPU Information:")
        for gpu in gpus:
            print(f"  {gpu}")
    print("\n")

# %% [markdown]
# ## Running the complete training and testing pipeline

# %%
def run():
    # Print version information for the libraries
    print_versions()

    # 1. Load and preprocess images
    print("\n" + "="*50)
    print("Step 1: Loading and preprocessing images...")

    # load the images and preprocess them with Keras util functions. 
    # send the root folder that contains the blocked and notblocked 
    images, labels = load_and_preprocess_images('../data')  
    print("Normalizing images...")
    images = normalize_images(images)

    # 2. Split the dataset
    print("\n" + "="*50)
    print("Step 2: Splitting dataset into training and testing sets...")
    X_train, X_test, y_train, y_test = split_dataset(images, labels, test_size=0.2)

    print(f"\nDataset sizes:")
    print(f"Training images: {len(X_train)}")
    print(f"Testing images: {len(X_test)}")

    # 3. Create and compile the model
    print("\n" + "="*50)
    print("Step 3: Creating and compiling model...")
    model = create_model()
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    # 4. Train the model
    print("\n" + "="*50)
    print("Step 4: Training model...")
    history = train_model(model, X_train, y_train)

    # 5. Evaluate the model
    print("\n" + "="*50)
    print("Step 5: Evaluating model...")
    metrics = evaluate_model(model, X_test, y_test)
    print(f"\nTest accuracy: {metrics['test_accuracy']:.4f}")
    print(f"Test loss: {metrics['test_loss']:.4f}")

    # 6. Plot training history
    print("\n" + "="*50)
    print("Step 6: Plotting training history...")
    plot_training_history(history)

# %%
run()
# Out:
# Package versions:
# Python: 3.9.18
# TensorFlow: 2.16.2
# NumPy: 1.26.4
# Scikit-learn: 1.5.2
# Matplotlib: 3.9.3
# Keras: 3.7.0
#
# GPU Information:
#   PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
#
#
#
# ==================================================
# Step 1: Loading and preprocessing images...
#
# Loading images with blocked bike lanes:
# Processing blocked image 25/2186
# Processing blocked image 50/2186
# Processing blocked image 75/2186
# Processing blocked image 100/2186
# Processing blocked image 125/2186
# Processing blocked image 150/2186
# Processing blocked image 175/2186
# Processing blocked image 200/2186
# Processing blocked image 225/2186
# Processing blocked image 250/2186
# Processing blocked image 275/2186
# Processing blocked image 300/2186
# Processing blocked image 325/2186
# Processing blocked image 350/2186
# Processing blocked image 375/2186
# Processing blocked image 400/2186
# Processing blocked image 425/2186
# Processing blocked image 450/2186
# Processing blocked image 475/2186
# Processing blocked image 500/2186
# Processing blocked image 525/2186
# Processing blocked image 550/2186
# Processing blocked image 575/2186
# Processing blocked image 600/2186
# Processing blocked image 625/2186
# Processing blocked image 650/2186
# Processing blocked image 675/2186
# Processing blocked image 700/2186
# Processing blocked image 725/2186
# Processing blocked image 750/2186
# Processing blocked image 775/2186
# Processing blocked image 800/2186
# Processing blocked image 825/2186
# Processing blocked image 850/2186
# Processing blocked image 875/2186
# Processing blocked image 900/2186
# Processing blocked image 925/2186
# Processing blocked image 950/2186
# Processing blocked image 975/2186
# Processing blocked image 1000/2186
# Processing blocked image 1025/2186
# Processing blocked image 1050/2186
# Processing blocked image 1075/2186
# Processing blocked image 1100/2186
# Processing blocked image 1125/2186
# Processing blocked image 1150/2186
# Processing blocked image 1175/2186
# Processing blocked image 1200/2186
# Processing blocked image 1225/2186
# Processing blocked image 1250/2186
# Processing blocked image 1275/2186
# Processing blocked image 1300/2186
# Processing blocked image 1325/2186
# Processing blocked image 1350/2186
# Processing blocked image 1375/2186
# Processing blocked image 1400/2186
# Processing blocked image 1425/2186
# Processing blocked image 1450/2186
# Processing blocked image 1475/2186
# Processing blocked image 1500/2186
# Processing blocked image 1525/2186
# Processing blocked image 1550/2186
# Processing blocked image 1575/2186
# Processing blocked image 1600/2186
# Processing blocked image 1625/2186
# Processing blocked image 1650/2186
# Processing blocked image 1675/2186
# Processing blocked image 1700/2186
# Processing blocked image 1725/2186
# Processing blocked image 1750/2186
# Processing blocked image 1775/2186
# Processing blocked image 1800/2186
# Processing blocked image 1825/2186
# Processing blocked image 1850/2186
# Processing blocked image 1875/2186
# Processing blocked image 1900/2186
# Processing blocked image 1925/2186
# Processing blocked image 1950/2186
# Processing blocked image 1975/2186
# Processing blocked image 2000/2186
# Processing blocked image 2025/2186
# Processing blocked image 2050/2186
# Processing blocked image 2075/2186
# Processing blocked image 2100/2186
# Processing blocked image 2125/2186
# Processing blocked image 2150/2186
# Processing blocked image 2175/2186
#
# Loading images with unblocked bike lanes:
# Processing non-blocked image 25/1656
# Processing non-blocked image 50/1656
# Processing non-blocked image 75/1656
# Processing non-blocked image 100/1656
# Processing non-blocked image 125/1656
# Processing non-blocked image 150/1656
# Processing non-blocked image 175/1656
# Processing non-blocked image 200/1656
# Processing non-blocked image 225/1656
# Processing non-blocked image 250/1656
# Processing non-blocked image 275/1656
# Processing non-blocked image 300/1656
# Processing non-blocked image 325/1656
# Processing non-blocked image 350/1656
# Processing non-blocked image 375/1656
# Processing non-blocked image 400/1656
# Processing non-blocked image 425/1656
# Processing non-blocked image 450/1656
# Processing non-blocked image 475/1656
# Processing non-blocked image 500/1656
# Processing non-blocked image 525/1656
# Processing non-blocked image 550/1656
# Processing non-blocked image 575/1656
# Processing non-blocked image 600/1656
# Processing non-blocked image 625/1656
# Processing non-blocked image 650/1656
# Processing non-blocked image 675/1656
# Processing non-blocked image 700/1656
# Processing non-blocked image 725/1656
# Processing non-blocked image 750/1656
# Processing non-blocked image 775/1656
# Processing non-blocked image 800/1656
# Processing non-blocked image 825/1656
# Processing non-blocked image 850/1656
# Processing non-blocked image 875/1656
# Processing non-blocked image 900/1656
# Processing non-blocked image 925/1656
# Processing non-blocked image 950/1656
# Processing non-blocked image 975/1656
# Processing non-blocked image 1000/1656
# Processing non-blocked image 1025/1656
# Processing non-blocked image 1050/1656
# Processing non-blocked image 1075/1656
# Processing non-blocked image 1100/1656
# Processing non-blocked image 1125/1656
# Processing non-blocked image 1150/1656
# Processing non-blocked image 1175/1656
# Processing non-blocked image 1200/1656
# Processing non-blocked image 1225/1656
# Processing non-blocked image 1250/1656
# Processing non-blocked image 1275/1656
# Processing non-blocked image 1300/1656
# Processing non-blocked image 1325/1656
# Processing non-blocked image 1350/1656
# Processing non-blocked image 1375/1656
# Processing non-blocked image 1400/1656
# Processing non-blocked image 1425/1656
# Processing non-blocked image 1450/1656
# Processing non-blocked image 1475/1656
# Processing non-blocked image 1500/1656
# Processing non-blocked image 1525/1656
# Processing non-blocked image 1550/1656
# Processing non-blocked image 1575/1656
# Processing non-blocked image 1600/1656
# Processing non-blocked image 1625/1656
# Processing non-blocked image 1650/1656
# Normalizing images...
#
# ==================================================
# Step 2: Splitting dataset into training and testing sets...
#
# Dataset sizes:
# Training images: 3073
# Testing images: 769
#
# ==================================================
# Step 3: Creating and compiling model...
#
# ==================================================
# Step 4: Training model...
#
# Training with 20 epochs, batch size 64
# Using 20.0% of training data for validation
# /Users/nickmeeks/.pyenv/versions/3.9.18/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-12-09 13:26:28.729519: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2024-12-09 13:26:28.729543: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-12-09 13:26:28.729549: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-12-09 13:26:28.729565: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-09 13:26:28.729575: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/20
# 2024-12-09 13:26:31.194843: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# ........
# Epoch 2/20
# ........
# Epoch 3/20
# ........
# Epoch 4/20
# ........
# Epoch 5/20
# ........
# Epoch 6/20
# ........
# Epoch 7/20
# ........
# Epoch 8/20
# ........
# Epoch 9/20
# ........
# Epoch 10/20
# ........
# Epoch 11/20
# ........
# Epoch 12/20
# ........
# Epoch 13/20
# ........
# Epoch 14/20
# ........
# Epoch 15/20
# ........
# Epoch 16/20
# ........
# Epoch 17/20
# ........
# Epoch 18/20
# ........
# Epoch 19/20
# ........
# Epoch 20/20
# ........
# ==================================================
# Step 5: Evaluating model...
#
# Evaluating model on test data...
# Evaluation complete!
#
# Test accuracy: 0.8778
# Test loss: 0.5081
#
# ==================================================
# Step 6: Plotting training history...
#
# Generating training history plots...
# Displaying plots...

# %% [markdown]
# Overfitting is very obvious, but that's ok, we wanted to see if overfitting was even possible as we learned.

# %%
""" Now I'm going to add dropout to see if we can combat some of the overfitting. """

def create_model():
    """
    Creates a CNN model for binary image classification (blocked vs not blocked).
    Architecture: 3 Conv2D layers with max pooling, followed by dense layers.
    """
    model = models.Sequential([
        # First Convolutional Layer
        # 32 filters of size 3x3, ReLU activation
        # Input shape: 224x224 RGB images (3 channels)
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        # Max Pooling: Reduces spatial dimensions by half (112x112)
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Second Convolutional Layer
        # 64 filters of size 3x3, increased filters for more feature detection
        layers.Conv2D(64, (3, 3), activation='relu'),
        # Max Pooling: Further reduces dimensions (56x56)
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Third Convolutional Layer
        # 64 filters of size 3x3, maintains number of filters
        layers.Conv2D(64, (3, 3), activation='relu'),
        
        # Flatten: Converts 3D feature maps to 1D vector
        layers.Flatten(),
        
        # Dense Layer: 64 neurons for high-level feature combination
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.5), # higher dropout rate because it's a Dense
        
        # Output Layer: Single neuron with sigmoid for binary classification
        # Output: 0 (not blocked) or 1 (blocked)
        layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
# Print version information for the libraries
print_versions()

# 1. Load and preprocess images
print("\n" + "="*50)
print("Step 1: Loading and preprocessing images...")

# load the images and preprocess them with Keras util functions. 
# send the root folder that contains the blocked and notblocked 
images, labels = load_and_preprocess_images('Bikelane_Detector/data')  
print("Normalizing images...")
images = normalize_images(images)

# 2. Split the dataset
print("\n" + "="*50)
print("Step 2: Splitting dataset into training and testing sets...")
X_train, X_test, y_train, y_test = split_dataset(images, labels, test_size=0.2)

print(f"\nDataset sizes:")
print(f"Training images: {len(X_train)}")
print(f"Testing images: {len(X_test)}")

# 3. Create and compile the model
print("\n" + "="*50)
print("Step 3: Creating and compiling model...")
model = create_model()
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# 4. Train the model
print("\n" + "="*50)
print("Step 4: Training model...")
history = train_model(model, X_train, y_train)

# 5. Evaluate the model
print("\n" + "="*50)
print("Step 5: Evaluating model...")
metrics = evaluate_model(model, X_test, y_test)
print(f"\nTest accuracy: {metrics['test_accuracy']:.4f}")
print(f"Test loss: {metrics['test_loss']:.4f}")

# 6. Plot training history
print("\n" + "="*50)
print("Step 6: Plotting training history...")
plot_training_history(history)
# Out:
# Package versions:
# Python: 3.11.6
# TensorFlow: 2.16.2
# NumPy: 1.26.2
# Scikit-learn: 1.4.1.post1
# Matplotlib: 3.8.3
# Keras: 3.6.0
#
# GPU Information:
#   PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
#
#
#
# ==================================================
# Step 1: Loading and preprocessing images...
#
# Loading images with blocked bike lanes:
# Processing blocked image 25/2186
# Processing blocked image 50/2186
# Processing blocked image 75/2186
# Processing blocked image 100/2186
# Processing blocked image 125/2186
# Processing blocked image 150/2186
# Processing blocked image 175/2186
# Processing blocked image 200/2186
# Processing blocked image 225/2186
# Processing blocked image 250/2186
# Processing blocked image 275/2186
# Processing blocked image 300/2186
# Processing blocked image 325/2186
# Processing blocked image 350/2186
# Processing blocked image 375/2186
# Processing blocked image 400/2186
# Processing blocked image 425/2186
# Processing blocked image 450/2186
# Processing blocked image 475/2186
# Processing blocked image 500/2186
# Processing blocked image 525/2186
# Processing blocked image 550/2186
# Processing blocked image 575/2186
# Processing blocked image 600/2186
# Processing blocked image 625/2186
# Processing blocked image 650/2186
# Processing blocked image 675/2186
# Processing blocked image 700/2186
# Processing blocked image 725/2186
# Processing blocked image 750/2186
# Processing blocked image 775/2186
# Processing blocked image 800/2186
# Processing blocked image 825/2186
# Processing blocked image 850/2186
# Processing blocked image 875/2186
# Processing blocked image 900/2186
# Processing blocked image 925/2186
# Processing blocked image 950/2186
# Processing blocked image 975/2186
# Processing blocked image 1000/2186
# Processing blocked image 1025/2186
# Processing blocked image 1050/2186
# Processing blocked image 1075/2186
# Processing blocked image 1100/2186
# Processing blocked image 1125/2186
# Processing blocked image 1150/2186
# Processing blocked image 1175/2186
# Processing blocked image 1200/2186
# Processing blocked image 1225/2186
# Processing blocked image 1250/2186
# Processing blocked image 1275/2186
# Processing blocked image 1300/2186
# Processing blocked image 1325/2186
# Processing blocked image 1350/2186
# Processing blocked image 1375/2186
# Processing blocked image 1400/2186
# Processing blocked image 1425/2186
# Processing blocked image 1450/2186
# Processing blocked image 1475/2186
# Processing blocked image 1500/2186
# Processing blocked image 1525/2186
# Processing blocked image 1550/2186
# Processing blocked image 1575/2186
# Processing blocked image 1600/2186
# Processing blocked image 1625/2186
# Processing blocked image 1650/2186
# Processing blocked image 1675/2186
# Processing blocked image 1700/2186
# Processing blocked image 1725/2186
# Processing blocked image 1750/2186
# Processing blocked image 1775/2186
# Processing blocked image 1800/2186
# Processing blocked image 1825/2186
# Processing blocked image 1850/2186
# Processing blocked image 1875/2186
# Processing blocked image 1900/2186
# Processing blocked image 1925/2186
# Processing blocked image 1950/2186
# Processing blocked image 1975/2186
# Processing blocked image 2000/2186
# Processing blocked image 2025/2186
# Processing blocked image 2050/2186
# Processing blocked image 2075/2186
# Processing blocked image 2100/2186
# Processing blocked image 2125/2186
# Processing blocked image 2150/2186
# Processing blocked image 2175/2186
#
# Loading images with unblocked bike lanes:
# Processing non-blocked image 25/1656
# Processing non-blocked image 50/1656
# Processing non-blocked image 75/1656
# Processing non-blocked image 100/1656
# Processing non-blocked image 125/1656
# Processing non-blocked image 150/1656
# Processing non-blocked image 175/1656
# Processing non-blocked image 200/1656
# Processing non-blocked image 225/1656
# Processing non-blocked image 250/1656
# Processing non-blocked image 275/1656
# Processing non-blocked image 300/1656
# Processing non-blocked image 325/1656
# Processing non-blocked image 350/1656
# Processing non-blocked image 375/1656
# Processing non-blocked image 400/1656
# Processing non-blocked image 425/1656
# Processing non-blocked image 450/1656
# Processing non-blocked image 475/1656
# Processing non-blocked image 500/1656
# Processing non-blocked image 525/1656
# Processing non-blocked image 550/1656
# Processing non-blocked image 575/1656
# Processing non-blocked image 600/1656
# Processing non-blocked image 625/1656
# Processing non-blocked image 650/1656
# Processing non-blocked image 675/1656
# Processing non-blocked image 700/1656
# Processing non-blocked image 725/1656
# Processing non-blocked image 750/1656
# Processing non-blocked image 775/1656
# Processing non-blocked image 800/1656
# Processing non-blocked image 825/1656
# Processing non-blocked image 850/1656
# Processing non-blocked image 875/1656
# Processing non-blocked image 900/1656
# Processing non-blocked image 925/1656
# Processing non-blocked image 950/1656
# Processing non-blocked image 975/1656
# Processing non-blocked image 1000/1656
# Processing non-blocked image 1025/1656
# Processing non-blocked image 1050/1656
# Processing non-blocked image 1075/1656
# Processing non-blocked image 1100/1656
# Processing non-blocked image 1125/1656
# Processing non-blocked image 1150/1656
# Processing non-blocked image 1175/1656
# Processing non-blocked image 1200/1656
# Processing non-blocked image 1225/1656
# Processing non-blocked image 1250/1656
# Processing non-blocked image 1275/1656
# Processing non-blocked image 1300/1656
# Processing non-blocked image 1325/1656
# Processing non-blocked image 1350/1656
# Processing non-blocked image 1375/1656
# Processing non-blocked image 1400/1656
# Processing non-blocked image 1425/1656
# Processing non-blocked image 1450/1656
# Processing non-blocked image 1475/1656
# Processing non-blocked image 1500/1656
# Processing non-blocked image 1525/1656
# Processing non-blocked image 1550/1656
# Processing non-blocked image 1575/1656
# Processing non-blocked image 1600/1656
# Processing non-blocked image 1625/1656
# Processing non-blocked image 1650/1656
# Normalizing images...
#
# ==================================================
# Step 2: Splitting dataset into training and testing sets...
#
# Dataset sizes:
# Training images: 3073
# Testing images: 769
#
# ==================================================
# Step 3: Creating and compiling model...
#
# ==================================================
# Step 4: Training model...
#
# Training with 40 epochs, batch size 64
# Using 20.0% of training data for validation
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/40
# ........
# Epoch 2/40
# ........
# Epoch 3/40
# ........
# Epoch 4/40
# ........
# Epoch 5/40
# ........
# Epoch 6/40
# ........
# Epoch 7/40
# ........
# Epoch 8/40
# ........
# Epoch 9/40
# ........
# Epoch 10/40
# ........
# Epoch 11/40
# ........
# Epoch 12/40
# ........
# Epoch 13/40
# ........
# Epoch 14/40
# ........
# Epoch 15/40
# ........
# Epoch 16/40
# ........
# Epoch 17/40
# ........
# Epoch 18/40
# ........
# Epoch 19/40
# ........
# Epoch 20/40
# ........
# Epoch 21/40
# ........
# Epoch 22/40
# ........
# Epoch 23/40
# ........
# Epoch 24/40
# ........
# Epoch 25/40
# ........
# Epoch 26/40
# ........
# Epoch 27/40
# ........
# Epoch 28/40
# ........
# Epoch 29/40
# ........
# Epoch 30/40
# ........
# Epoch 31/40
# ........
# Epoch 32/40
# ........
# Epoch 33/40
# ........
# Epoch 34/40
# ........
# Epoch 35/40
# ........
# Epoch 36/40
# ........
# Epoch 37/40
# ........
# Epoch 38/40
# ........
# Epoch 39/40
# ........
# Epoch 40/40
# ........
# ==================================================
# Step 5: Evaluating model...
#
# Evaluating model on test data...
# Evaluation complete!
#
# Test accuracy: 0.8583
# Test loss: 0.7525
#
# ==================================================
# Step 6: Plotting training history...
#
# Generating training history plots...
# Displaying plots...

# %% [markdown]
# Slight improvement, but still not great. I'm going to add dropout right at the input stage and increase rates across the board.

# %%
def create_model():
    """
    Creates a CNN model for binary image classification (blocked vs not blocked).
    Architecture: 3 Conv2D layers with max pooling, followed by dense layers.
    """
    model = models.Sequential([
        #initial dropout
        layers.Dropout(0.5),


        # First Convolutional Layer
        # 32 filters of size 3x3, ReLU activation
        # Input shape: 224x224 RGB images (3 channels)
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        # Max Pooling: Reduces spatial dimensions by half (112x112)
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.5),
        
        # Second Convolutional Layer
        # 64 filters of size 3x3, increased filters for more feature detection
        layers.Conv2D(64, (3, 3), activation='relu'),
        # Max Pooling: Further reduces dimensions (56x56)
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.5),
        
        # Third Convolutional Layer
        # 64 filters of size 3x3, maintains number of filters
        layers.Conv2D(64, (3, 3), activation='relu'),
        
        # Flatten: Converts 3D feature maps to 1D vector
        layers.Flatten(),
        
        # Dense Layer: 64 neurons for high-level feature combination
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.5),
        
        # Output Layer: Single neuron with sigmoid for binary classification
        # Output: 0 (not blocked) or 1 (blocked)
        layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
run()
# Out:
# Package versions:
# Python: 3.11.6
# TensorFlow: 2.16.2
# NumPy: 1.26.2
# Scikit-learn: 1.4.1.post1
# Matplotlib: 3.8.3
# Keras: 3.6.0
#
# GPU Information:
#   PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
#
#
#
# ==================================================
# Step 1: Loading and preprocessing images...
#
# Loading images with blocked bike lanes:
# Processing blocked image 25/2186
# Processing blocked image 50/2186
# Processing blocked image 75/2186
# Processing blocked image 100/2186
# Processing blocked image 125/2186
# Processing blocked image 150/2186
# Processing blocked image 175/2186
# Processing blocked image 200/2186
# Processing blocked image 225/2186
# Processing blocked image 250/2186
# Processing blocked image 275/2186
# Processing blocked image 300/2186
# Processing blocked image 325/2186
# Processing blocked image 350/2186
# Processing blocked image 375/2186
# Processing blocked image 400/2186
# Processing blocked image 425/2186
# Processing blocked image 450/2186
# Processing blocked image 475/2186
# Processing blocked image 500/2186
# Processing blocked image 525/2186
# Processing blocked image 550/2186
# Processing blocked image 575/2186
# Processing blocked image 600/2186
# Processing blocked image 625/2186
# Processing blocked image 650/2186
# Processing blocked image 675/2186
# Processing blocked image 700/2186
# Processing blocked image 725/2186
# Processing blocked image 750/2186
# Processing blocked image 775/2186
# Processing blocked image 800/2186
# Processing blocked image 825/2186
# Processing blocked image 850/2186
# Processing blocked image 875/2186
# Processing blocked image 900/2186
# Processing blocked image 925/2186
# Processing blocked image 950/2186
# Processing blocked image 975/2186
# Processing blocked image 1000/2186
# Processing blocked image 1025/2186
# Processing blocked image 1050/2186
# Processing blocked image 1075/2186
# Processing blocked image 1100/2186
# Processing blocked image 1125/2186
# Processing blocked image 1150/2186
# Processing blocked image 1175/2186
# Processing blocked image 1200/2186
# Processing blocked image 1225/2186
# Processing blocked image 1250/2186
# Processing blocked image 1275/2186
# Processing blocked image 1300/2186
# Processing blocked image 1325/2186
# Processing blocked image 1350/2186
# Processing blocked image 1375/2186
# Processing blocked image 1400/2186
# Processing blocked image 1425/2186
# Processing blocked image 1450/2186
# Processing blocked image 1475/2186
# Processing blocked image 1500/2186
# Processing blocked image 1525/2186
# Processing blocked image 1550/2186
# Processing blocked image 1575/2186
# Processing blocked image 1600/2186
# Processing blocked image 1625/2186
# Processing blocked image 1650/2186
# Processing blocked image 1675/2186
# Processing blocked image 1700/2186
# Processing blocked image 1725/2186
# Processing blocked image 1750/2186
# Processing blocked image 1775/2186
# Processing blocked image 1800/2186
# Processing blocked image 1825/2186
# Processing blocked image 1850/2186
# Processing blocked image 1875/2186
# Processing blocked image 1900/2186
# Processing blocked image 1925/2186
# Processing blocked image 1950/2186
# Processing blocked image 1975/2186
# Processing blocked image 2000/2186
# Processing blocked image 2025/2186
# Processing blocked image 2050/2186
# Processing blocked image 2075/2186
# Processing blocked image 2100/2186
# Processing blocked image 2125/2186
# Processing blocked image 2150/2186
# Processing blocked image 2175/2186
#
# Loading images with unblocked bike lanes:
# Processing non-blocked image 25/1656
# Processing non-blocked image 50/1656
# Processing non-blocked image 75/1656
# Processing non-blocked image 100/1656
# Processing non-blocked image 125/1656
# Processing non-blocked image 150/1656
# Processing non-blocked image 175/1656
# Processing non-blocked image 200/1656
# Processing non-blocked image 225/1656
# Processing non-blocked image 250/1656
# Processing non-blocked image 275/1656
# Processing non-blocked image 300/1656
# Processing non-blocked image 325/1656
# Processing non-blocked image 350/1656
# Processing non-blocked image 375/1656
# Processing non-blocked image 400/1656
# Processing non-blocked image 425/1656
# Processing non-blocked image 450/1656
# Processing non-blocked image 475/1656
# Processing non-blocked image 500/1656
# Processing non-blocked image 525/1656
# Processing non-blocked image 550/1656
# Processing non-blocked image 575/1656
# Processing non-blocked image 600/1656
# Processing non-blocked image 625/1656
# Processing non-blocked image 650/1656
# Processing non-blocked image 675/1656
# Processing non-blocked image 700/1656
# Processing non-blocked image 725/1656
# Processing non-blocked image 750/1656
# Processing non-blocked image 775/1656
# Processing non-blocked image 800/1656
# Processing non-blocked image 825/1656
# Processing non-blocked image 850/1656
# Processing non-blocked image 875/1656
# Processing non-blocked image 900/1656
# Processing non-blocked image 925/1656
# Processing non-blocked image 950/1656
# Processing non-blocked image 975/1656
# Processing non-blocked image 1000/1656
# Processing non-blocked image 1025/1656
# Processing non-blocked image 1050/1656
# Processing non-blocked image 1075/1656
# Processing non-blocked image 1100/1656
# Processing non-blocked image 1125/1656
# Processing non-blocked image 1150/1656
# Processing non-blocked image 1175/1656
# Processing non-blocked image 1200/1656
# Processing non-blocked image 1225/1656
# Processing non-blocked image 1250/1656
# Processing non-blocked image 1275/1656
# Processing non-blocked image 1300/1656
# Processing non-blocked image 1325/1656
# Processing non-blocked image 1350/1656
# Processing non-blocked image 1375/1656
# Processing non-blocked image 1400/1656
# Processing non-blocked image 1425/1656
# Processing non-blocked image 1450/1656
# Processing non-blocked image 1475/1656
# Processing non-blocked image 1500/1656
# Processing non-blocked image 1525/1656
# Processing non-blocked image 1550/1656
# Processing non-blocked image 1575/1656
# Processing non-blocked image 1600/1656
# Processing non-blocked image 1625/1656
# Processing non-blocked image 1650/1656
# Normalizing images...
#
# ==================================================
# Step 2: Splitting dataset into training and testing sets...
#
# Dataset sizes:
# Training images: 3073
# Testing images: 769
#
# ==================================================
# Step 3: Creating and compiling model...
#
# ==================================================
# Step 4: Training model...
#
# Training with 40 epochs, batch size 64
# Using 20.0% of training data for validation
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/40
# ........
# Epoch 2/40
# ........
# Epoch 3/40
# ........
# Epoch 4/40
# ........
# Epoch 5/40
# ........
# Epoch 6/40
# ........
# Epoch 7/40
# ........
# Epoch 8/40
# ........
# Epoch 9/40
# ........
# Epoch 10/40
# ........
# Epoch 11/40
# ........
# Epoch 12/40
# ........
# Epoch 13/40
# ........
# Epoch 14/40
# ........
# Epoch 15/40
# ........
# Epoch 16/40
# ........
# Epoch 17/40
# ........
# Epoch 18/40
# ........
# Epoch 19/40
# ........
# Epoch 20/40
# ........
# Epoch 21/40
# ........
# Epoch 22/40
# ........
# Epoch 23/40
# ........
# Epoch 24/40
# ........
# Epoch 25/40
# ........
# Epoch 26/40
# ........
# Epoch 27/40
# ........
# Epoch 28/40
# ........
# Epoch 29/40
# ........
# Epoch 30/40
# ........
# Epoch 31/40
# ........
# Epoch 32/40
# ........
# Epoch 33/40
# ........
# Epoch 34/40
# ........
# Epoch 35/40
# ........
# Epoch 36/40
# ........
# Epoch 37/40
# ........
# Epoch 38/40
# ........
# Epoch 39/40
# ........
# Epoch 40/40
# ........
# ==================================================
# Step 5: Evaluating model...
#
# Evaluating model on test data...
# Evaluation complete!
#
# Test accuracy: 0.6541
# Test loss: 0.6072
#
# ==================================================
# Step 6: Plotting training history...
#
# Generating training history plots...
# Displaying plots...

# %% [markdown]
# That was much worse. I think too much dropout, so I'll try just input dropout and compare it to the one before last.

# %%
def create_model():
    """
    Creates a CNN model for binary image classification (blocked vs not blocked).
    Architecture: 3 Conv2D layers with max pooling, followed by dense layers.
    """
    model = models.Sequential([
        #initial dropout
        layers.Dropout(0.5),


        # First Convolutional Layer
        # 32 filters of size 3x3, ReLU activation
        # Input shape: 224x224 RGB images (3 channels)
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        # Max Pooling: Reduces spatial dimensions by half (112x112)
        layers.MaxPooling2D((2, 2)),
        #layers.Dropout(0.5),
        
        # Second Convolutional Layer
        # 64 filters of size 3x3, increased filters for more feature detection
        layers.Conv2D(64, (3, 3), activation='relu'),
        # Max Pooling: Further reduces dimensions (56x56)
        layers.MaxPooling2D((2, 2)),
        #layers.Dropout(0.5),
        
        # Third Convolutional Layer
        # 64 filters of size 3x3, maintains number of filters
        layers.Conv2D(64, (3, 3), activation='relu'),
        
        # Flatten: Converts 3D feature maps to 1D vector
        layers.Flatten(),
        
        # Dense Layer: 64 neurons for high-level feature combination
        layers.Dense(64, activation='relu'),
        #layers.Dropout(0.5),
        
        # Output Layer: Single neuron with sigmoid for binary classification
        # Output: 0 (not blocked) or 1 (blocked)
        layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
run()
# Out:
# Package versions:
# Python: 3.11.6
# TensorFlow: 2.16.2
# NumPy: 1.26.2
# Scikit-learn: 1.4.1.post1
# Matplotlib: 3.8.3
# Keras: 3.6.0
#
# GPU Information:
#   PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
#
#
#
# ==================================================
# Step 1: Loading and preprocessing images...
#
# Loading images with blocked bike lanes:
# Processing blocked image 25/2186
# Processing blocked image 50/2186
# Processing blocked image 75/2186
# Processing blocked image 100/2186
# Processing blocked image 125/2186
# Processing blocked image 150/2186
# Processing blocked image 175/2186
# Processing blocked image 200/2186
# Processing blocked image 225/2186
# Processing blocked image 250/2186
# Processing blocked image 275/2186
# Processing blocked image 300/2186
# Processing blocked image 325/2186
# Processing blocked image 350/2186
# Processing blocked image 375/2186
# Processing blocked image 400/2186
# Processing blocked image 425/2186
# Processing blocked image 450/2186
# Processing blocked image 475/2186
# Processing blocked image 500/2186
# Processing blocked image 525/2186
# Processing blocked image 550/2186
# Processing blocked image 575/2186
# Processing blocked image 600/2186
# Processing blocked image 625/2186
# Processing blocked image 650/2186
# Processing blocked image 675/2186
# Processing blocked image 700/2186
# Processing blocked image 725/2186
# Processing blocked image 750/2186
# Processing blocked image 775/2186
# Processing blocked image 800/2186
# Processing blocked image 825/2186
# Processing blocked image 850/2186
# Processing blocked image 875/2186
# Processing blocked image 900/2186
# Processing blocked image 925/2186
# Processing blocked image 950/2186
# Processing blocked image 975/2186
# Processing blocked image 1000/2186
# Processing blocked image 1025/2186
# Processing blocked image 1050/2186
# Processing blocked image 1075/2186
# Processing blocked image 1100/2186
# Processing blocked image 1125/2186
# Processing blocked image 1150/2186
# Processing blocked image 1175/2186
# Processing blocked image 1200/2186
# Processing blocked image 1225/2186
# Processing blocked image 1250/2186
# Processing blocked image 1275/2186
# Processing blocked image 1300/2186
# Processing blocked image 1325/2186
# Processing blocked image 1350/2186
# Processing blocked image 1375/2186
# Processing blocked image 1400/2186
# Processing blocked image 1425/2186
# Processing blocked image 1450/2186
# Processing blocked image 1475/2186
# Processing blocked image 1500/2186
# Processing blocked image 1525/2186
# Processing blocked image 1550/2186
# Processing blocked image 1575/2186
# Processing blocked image 1600/2186
# Processing blocked image 1625/2186
# Processing blocked image 1650/2186
# Processing blocked image 1675/2186
# Processing blocked image 1700/2186
# Processing blocked image 1725/2186
# Processing blocked image 1750/2186
# Processing blocked image 1775/2186
# Processing blocked image 1800/2186
# Processing blocked image 1825/2186
# Processing blocked image 1850/2186
# Processing blocked image 1875/2186
# Processing blocked image 1900/2186
# Processing blocked image 1925/2186
# Processing blocked image 1950/2186
# Processing blocked image 1975/2186
# Processing blocked image 2000/2186
# Processing blocked image 2025/2186
# Processing blocked image 2050/2186
# Processing blocked image 2075/2186
# Processing blocked image 2100/2186
# Processing blocked image 2125/2186
# Processing blocked image 2150/2186
# Processing blocked image 2175/2186
#
# Loading images with unblocked bike lanes:
# Processing non-blocked image 25/1656
# Processing non-blocked image 50/1656
# Processing non-blocked image 75/1656
# Processing non-blocked image 100/1656
# Processing non-blocked image 125/1656
# Processing non-blocked image 150/1656
# Processing non-blocked image 175/1656
# Processing non-blocked image 200/1656
# Processing non-blocked image 225/1656
# Processing non-blocked image 250/1656
# Processing non-blocked image 275/1656
# Processing non-blocked image 300/1656
# Processing non-blocked image 325/1656
# Processing non-blocked image 350/1656
# Processing non-blocked image 375/1656
# Processing non-blocked image 400/1656
# Processing non-blocked image 425/1656
# Processing non-blocked image 450/1656
# Processing non-blocked image 475/1656
# Processing non-blocked image 500/1656
# Processing non-blocked image 525/1656
# Processing non-blocked image 550/1656
# Processing non-blocked image 575/1656
# Processing non-blocked image 600/1656
# Processing non-blocked image 625/1656
# Processing non-blocked image 650/1656
# Processing non-blocked image 675/1656
# Processing non-blocked image 700/1656
# Processing non-blocked image 725/1656
# Processing non-blocked image 750/1656
# Processing non-blocked image 775/1656
# Processing non-blocked image 800/1656
# Processing non-blocked image 825/1656
# Processing non-blocked image 850/1656
# Processing non-blocked image 875/1656
# Processing non-blocked image 900/1656
# Processing non-blocked image 925/1656
# Processing non-blocked image 950/1656
# Processing non-blocked image 975/1656
# Processing non-blocked image 1000/1656
# Processing non-blocked image 1025/1656
# Processing non-blocked image 1050/1656
# Processing non-blocked image 1075/1656
# Processing non-blocked image 1100/1656
# Processing non-blocked image 1125/1656
# Processing non-blocked image 1150/1656
# Processing non-blocked image 1175/1656
# Processing non-blocked image 1200/1656
# Processing non-blocked image 1225/1656
# Processing non-blocked image 1250/1656
# Processing non-blocked image 1275/1656
# Processing non-blocked image 1300/1656
# Processing non-blocked image 1325/1656
# Processing non-blocked image 1350/1656
# Processing non-blocked image 1375/1656
# Processing non-blocked image 1400/1656
# Processing non-blocked image 1425/1656
# Processing non-blocked image 1450/1656
# Processing non-blocked image 1475/1656
# Processing non-blocked image 1500/1656
# Processing non-blocked image 1525/1656
# Processing non-blocked image 1550/1656
# Processing non-blocked image 1575/1656
# Processing non-blocked image 1600/1656
# Processing non-blocked image 1625/1656
# Processing non-blocked image 1650/1656
# Normalizing images...
#
# ==================================================
# Step 2: Splitting dataset into training and testing sets...
#
# Dataset sizes:
# Training images: 3073
# Testing images: 769
#
# ==================================================
# Step 3: Creating and compiling model...
#
# ==================================================
# Step 4: Training model...
#
# Training with 40 epochs, batch size 64
# Using 20.0% of training data for validation
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/40
# ........
# Epoch 2/40
# ........
# Epoch 3/40
# ........
# Epoch 4/40
# ........
# Epoch 5/40
# ........
# Epoch 6/40
# ........
# Epoch 7/40
# ........
# Epoch 8/40
# ........
# Epoch 9/40
# ........
# Epoch 10/40
# ........
# Epoch 11/40
# ........
# Epoch 12/40
# ........
# Epoch 13/40
# ........
# Epoch 14/40
# ........
# Epoch 15/40
# ........
# Epoch 16/40
# ........
# Epoch 17/40
# ........
# Epoch 18/40
# ........
# Epoch 19/40
# ........
# Epoch 20/40
# ........
# Epoch 21/40
# ........
# Epoch 22/40
# ........
# Epoch 23/40
# ........
# Epoch 24/40
# ........
# Epoch 25/40
# ........
# Epoch 26/40
# ........
# Epoch 27/40
# ........
# Epoch 28/40
# ........
# Epoch 29/40
# ........
# Epoch 30/40
# ........
# Epoch 31/40
# ........
# Epoch 32/40
# ........
# Epoch 33/40
# ........
# Epoch 34/40
# ........
# Epoch 35/40
# ........
# Epoch 36/40
# ........
# Epoch 37/40
# ........
# Epoch 38/40
# ........
# Epoch 39/40
# ........
# Epoch 40/40
# ........
# ==================================================
# Step 5: Evaluating model...
#
# Evaluating model on test data...
# Evaluation complete!
#
# Test accuracy: 0.8270
# Test loss: 0.4379
#
# ==================================================
# Step 6: Plotting training history...
#
# Generating training history plots...
# Displaying plots...

# %% [markdown]
# That was also worse, so we'll revert to the best of the dropout trials.
# Also, it looks like for the better performing models, 10 epochs is the point that overfitting starts to occur.
# So, I'm going to implement early stopping instead of just relying on hard-coded epochs.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define the early stopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',  # Metric to monitor
    patience=5,              # Number of epochs to wait before stopping
    min_delta=0.01,          # Minimum change in the monitored metric to qualify as an improvement
    restore_best_weights=True  # Restore model weights from the best epoch
)

# %%
def train_model(model, X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2):
    """Train the model and return training history."""
    print(f"\nTraining with {epochs} epochs, batch size {batch_size}")
    print(f"Using {validation_split*100}% of training data for validation")
    
    class TrainingProgressCallback(tf.keras.callbacks.Callback):
        def on_epoch_begin(self, epoch, logs=None):
            print(f"\nEpoch {epoch + 1}/{epochs}")
        
        def on_batch_end(self, batch, logs=None):
            if batch % 5 == 0:  # Show progress every 5 batches
                print(".", end="", flush=True)
    
    return model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=validation_split,
        callbacks=[TrainingProgressCallback(), early_stopping], # ADDED EARLY STOPPING
        verbose=0
    )

def evaluate_model(model, X_test, y_test):
    """Evaluate model on test data and return metrics."""
    print("\nEvaluating model on test data...")
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    metrics = {
        'test_loss': test_loss,
        'test_accuracy': test_accuracy
    }
    print(f"Evaluation complete!")
    return metrics

# %% [markdown]
# I'm going to re-run with the best dropout we tested and early stopping. I'm also going to add another Conv2D layer to try to increase accuracy.

# %%
def create_model():
    """
    Creates a CNN model for binary image classification (blocked vs not blocked).
    Architecture: 3 Conv2D layers with max pooling, followed by dense layers.
    """
    model = models.Sequential([
        # First Convolutional Layer
        # 32 filters of size 3x3, ReLU activation
        # Input shape: 224x224 RGB images (3 channels)
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        # Max Pooling: Reduces spatial dimensions by half (112x112)
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Second Convolutional Layer
        # 64 filters of size 3x3, increased filters for more feature detection
        layers.Conv2D(64, (3, 3), activation='relu'),
        # Max Pooling: Further reduces dimensions (56x56)
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Third Convolutional Layer
        # 64 filters of size 3x3, maintains number of filters
        layers.Conv2D(64, (3, 3), activation='relu'),

        # Fourth Convolutional Layer
        # 64 filters of size 3x3, maintains number of filters
        layers.Conv2D(64, (3, 3), activation='relu'),
        
        # Flatten: Converts 3D feature maps to 1D vector
        layers.Flatten(),
        
        # Dense Layer: 64 neurons for high-level feature combination
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.5), # higher dropout rate because it's a Dense
        
        # Output Layer: Single neuron with sigmoid for binary classification
        # Output: 0 (not blocked) or 1 (blocked)
        layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
run()
# Out:
# Package versions:
# Python: 3.11.6
# TensorFlow: 2.16.2
# NumPy: 1.26.2
# Scikit-learn: 1.4.1.post1
# Matplotlib: 3.8.3
# Keras: 3.6.0
#
# GPU Information:
#   PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
#
#
#
# ==================================================
# Step 1: Loading and preprocessing images...
#
# Loading images with blocked bike lanes:
# Processing blocked image 25/2186
# Processing blocked image 50/2186
# Processing blocked image 75/2186
# Processing blocked image 100/2186
# Processing blocked image 125/2186
# Processing blocked image 150/2186
# Processing blocked image 175/2186
# Processing blocked image 200/2186
# Processing blocked image 225/2186
# Processing blocked image 250/2186
# Processing blocked image 275/2186
# Processing blocked image 300/2186
# Processing blocked image 325/2186
# Processing blocked image 350/2186
# Processing blocked image 375/2186
# Processing blocked image 400/2186
# Processing blocked image 425/2186
# Processing blocked image 450/2186
# Processing blocked image 475/2186
# Processing blocked image 500/2186
# Processing blocked image 525/2186
# Processing blocked image 550/2186
# Processing blocked image 575/2186
# Processing blocked image 600/2186
# Processing blocked image 625/2186
# Processing blocked image 650/2186
# Processing blocked image 675/2186
# Processing blocked image 700/2186
# Processing blocked image 725/2186
# Processing blocked image 750/2186
# Processing blocked image 775/2186
# Processing blocked image 800/2186
# Processing blocked image 825/2186
# Processing blocked image 850/2186
# Processing blocked image 875/2186
# Processing blocked image 900/2186
# Processing blocked image 925/2186
# Processing blocked image 950/2186
# Processing blocked image 975/2186
# Processing blocked image 1000/2186
# Processing blocked image 1025/2186
# Processing blocked image 1050/2186
# Processing blocked image 1075/2186
# Processing blocked image 1100/2186
# Processing blocked image 1125/2186
# Processing blocked image 1150/2186
# Processing blocked image 1175/2186
# Processing blocked image 1200/2186
# Processing blocked image 1225/2186
# Processing blocked image 1250/2186
# Processing blocked image 1275/2186
# Processing blocked image 1300/2186
# Processing blocked image 1325/2186
# Processing blocked image 1350/2186
# Processing blocked image 1375/2186
# Processing blocked image 1400/2186
# Processing blocked image 1425/2186
# Processing blocked image 1450/2186
# Processing blocked image 1475/2186
# Processing blocked image 1500/2186
# Processing blocked image 1525/2186
# Processing blocked image 1550/2186
# Processing blocked image 1575/2186
# Processing blocked image 1600/2186
# Processing blocked image 1625/2186
# Processing blocked image 1650/2186
# Processing blocked image 1675/2186
# Processing blocked image 1700/2186
# Processing blocked image 1725/2186
# Processing blocked image 1750/2186
# Processing blocked image 1775/2186
# Processing blocked image 1800/2186
# Processing blocked image 1825/2186
# Processing blocked image 1850/2186
# Processing blocked image 1875/2186
# Processing blocked image 1900/2186
# Processing blocked image 1925/2186
# Processing blocked image 1950/2186
# Processing blocked image 1975/2186
# Processing blocked image 2000/2186
# Processing blocked image 2025/2186
# Processing blocked image 2050/2186
# Processing blocked image 2075/2186
# Processing blocked image 2100/2186
# Processing blocked image 2125/2186
# Processing blocked image 2150/2186
# Processing blocked image 2175/2186
#
# Loading images with unblocked bike lanes:
# Processing non-blocked image 25/1656
# Processing non-blocked image 50/1656
# Processing non-blocked image 75/1656
# Processing non-blocked image 100/1656
# Processing non-blocked image 125/1656
# Processing non-blocked image 150/1656
# Processing non-blocked image 175/1656
# Processing non-blocked image 200/1656
# Processing non-blocked image 225/1656
# Processing non-blocked image 250/1656
# Processing non-blocked image 275/1656
# Processing non-blocked image 300/1656
# Processing non-blocked image 325/1656
# Processing non-blocked image 350/1656
# Processing non-blocked image 375/1656
# Processing non-blocked image 400/1656
# Processing non-blocked image 425/1656
# Processing non-blocked image 450/1656
# Processing non-blocked image 475/1656
# Processing non-blocked image 500/1656
# Processing non-blocked image 525/1656
# Processing non-blocked image 550/1656
# Processing non-blocked image 575/1656
# Processing non-blocked image 600/1656
# Processing non-blocked image 625/1656
# Processing non-blocked image 650/1656
# Processing non-blocked image 675/1656
# Processing non-blocked image 700/1656
# Processing non-blocked image 725/1656
# Processing non-blocked image 750/1656
# Processing non-blocked image 775/1656
# Processing non-blocked image 800/1656
# Processing non-blocked image 825/1656
# Processing non-blocked image 850/1656
# Processing non-blocked image 875/1656
# Processing non-blocked image 900/1656
# Processing non-blocked image 925/1656
# Processing non-blocked image 950/1656
# Processing non-blocked image 975/1656
# Processing non-blocked image 1000/1656
# Processing non-blocked image 1025/1656
# Processing non-blocked image 1050/1656
# Processing non-blocked image 1075/1656
# Processing non-blocked image 1100/1656
# Processing non-blocked image 1125/1656
# Processing non-blocked image 1150/1656
# Processing non-blocked image 1175/1656
# Processing non-blocked image 1200/1656
# Processing non-blocked image 1225/1656
# Processing non-blocked image 1250/1656
# Processing non-blocked image 1275/1656
# Processing non-blocked image 1300/1656
# Processing non-blocked image 1325/1656
# Processing non-blocked image 1350/1656
# Processing non-blocked image 1375/1656
# Processing non-blocked image 1400/1656
# Processing non-blocked image 1425/1656
# Processing non-blocked image 1450/1656
# Processing non-blocked image 1475/1656
# Processing non-blocked image 1500/1656
# Processing non-blocked image 1525/1656
# Processing non-blocked image 1550/1656
# Processing non-blocked image 1575/1656
# Processing non-blocked image 1600/1656
# Processing non-blocked image 1625/1656
# Processing non-blocked image 1650/1656
# Normalizing images...
#
# ==================================================
# Step 2: Splitting dataset into training and testing sets...
#
# Dataset sizes:
# Training images: 3073
# Testing images: 769
#
# ==================================================
# Step 3: Creating and compiling model...
#
# ==================================================
# Step 4: Training model...
#
# Training with 40 epochs, batch size 64
# Using 20.0% of training data for validation
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/40
# ........
# Epoch 2/40
# ........
# Epoch 3/40
# ........
# Epoch 4/40
# ........
# Epoch 5/40
# ........
# Epoch 6/40
# ........
# Epoch 7/40
# ........
# Epoch 8/40
# ........
# Epoch 9/40
# ........
# Epoch 10/40
# ........
# Epoch 11/40
# ........
# Epoch 12/40
# ........
# Epoch 13/40
# ........
# Epoch 14/40
# ........
# ==================================================
# Step 5: Evaluating model...
#
# Evaluating model on test data...
# Evaluation complete!
#
# Test accuracy: 0.8322
# Test loss: 0.3678
#
# ==================================================
# Step 6: Plotting training history...
#
# Generating training history plots...
# Displaying plots...
